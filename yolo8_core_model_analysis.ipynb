# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
latency_bound = 900

# %% [markdown]
# ## Nano

# %%
## NANO
dfn0 = pd.read_csv('yolov8/logs/nano/dataset_yolo8n_b0_20240719_184512.csv')
dfn1 = pd.read_csv('yolov8/logs/nano/dataset_yolo8n_b1_20240719_194425.csv')
dfn15 = pd.read_csv('yolov8/logs/nano/dataset_yolo8n_b15_20240719_203732.csv')
dfn0.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721411e+09       nano     6.jpg               0.609235
# 1  1.721411e+09       nano     6.jpg               0.246938
# 2  1.721411e+09       nano     6.jpg               0.568292
# 3  1.721411e+09       nano     6.jpg               0.377092
# 4  1.721411e+09       nano     6.jpg               0.569254
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            4696.698427       5.334612  belgium   500       37.3  1000
# 1             369.429111       0.643364  belgium   500       37.3  1000
# 2             427.781105       1.027048  belgium   500       37.3  1000
# 3             391.561508       0.796242  belgium   500       37.3  1000
# 4             401.158094       0.998305  belgium   500       37.3  1000

# %%
svrn0 = dfn0[dfn0['Processing Delay (ms)'] > latency_bound] 
svrn0
#sla_violations = df[df['processing_delay (ms)'] > latency_bound]
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721411e+09       nano     6.jpg               0.609235
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            4696.698427       5.334612  belgium   500       37.3  1000

# %%
dfn1.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721415e+09       nano     6.jpg               0.451998
# 1  1.721415e+09       nano     6.jpg               0.443032
# 2  1.721415e+09       nano     6.jpg               0.284164
# 3  1.721415e+09       nano     6.jpg               0.233821
# 4  1.721415e+09       nano     6.jpg               0.366985
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            2671.942711       3.154818  belgium  1000       37.3  1000
# 1             197.436094       0.660015  belgium  1000       37.3  1000
# 2             203.385115       0.511434  belgium  1000       37.3  1000
# 3             205.877542       0.462633  belgium  1000       37.3  1000
# 4             200.825453       0.589062  belgium  1000       37.3  1000

# %%
svrn1 = dfn1[dfn1['Processing Delay (ms)'] > latency_bound] 
svrn1
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721415e+09       nano     6.jpg               0.451998
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            2671.942711       3.154818  belgium  1000       37.3  1000

# %%
dfn15.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721418e+09       nano     6.jpg               0.405259
# 1  1.721418e+09       nano     6.jpg               0.220766
# 2  1.721418e+09       nano     6.jpg               0.299032
# 3  1.721418e+09       nano     6.jpg               0.177716
# 4  1.721418e+09       nano     6.jpg               0.284670
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            2611.776829       3.062200  belgium  1500       37.3  1000
# 1             204.524755       0.447309  belgium  1500       37.3  1000
# 2             202.399731       0.536918  belgium  1500       37.3  1000
# 3             206.775188       0.404621  belgium  1500       37.3  1000
# 4             205.186844       0.513841  belgium  1500       37.3  1000

# %%
svrn15 = dfn15[dfn15['Processing Delay (ms)'] > latency_bound] 
svrn15
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721418e+09       nano     6.jpg               0.405259
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            2611.776829         3.0622  belgium  1500       37.3  1000

# %%
dfn0.shape, dfn1.shape, dfn15.shape
# Out:
# ((3148, 10), (4576, 10), (4934, 10))

# %%
plt.figure(figsize=(12,4))
plt.plot(dfn0.index[1:], dfn0['Processing Delay (ms)'][1:], label='Nano 500')
plt.plot(dfn1.index[1:], dfn1['Processing Delay (ms)'][1:], label='Nano 1000')
plt.plot(dfn15.index[1:], dfn15['Processing Delay (ms)'][1:], label='Nano 1500')

plt.grid()
plt.legend()
#plt.ylim([0,1000])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(dfn0.index[1:], dfn0['Processing Delay (ms)'][1:], label='500 - Nano')
plt.plot(dfs0.index[1:], dfs0['Processing Delay (ms)'][1:], label='500 - Small')
plt.plot(dfm0.index[1:], dfm0['Processing Delay (ms)'][1:], label='500 - Medium')

plt.grid()
plt.legend()
plt.ylim([0,00])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 plt.plot(dfn0.index[1:], dfn0['Processing Delay (ms)'][1:], label='500 - Nano')
#       3 plt.plot(dfs0.index[1:], dfs0['Processing Delay (ms)'][1:], label='500 - Small')
# ----> 4 plt.plot(dfm0.index[1:], dfm0['Processing Delay (ms)'][1:], label='500 - Medium')
#       6 plt.grid()
#       7 plt.legend()
#
# NameError: name 'dfm0' is not defined

# %% [markdown]
# ## Small

# %%
## SMALL
dfs0 = pd.read_csv('yolov8/logs/small/dataset_yolo8s_b0_20240719_220205.csv')
dfs1 = pd.read_csv('yolov8/logs/small/dataset_yolo8s_b1_20240719_213445.csv')
dfs15 = pd.read_csv('yolov8/logs/small/dataset_yolo8s_b15_20240719_210841.csv')
dfs0.shape, dfs1.shape, dfs15.shape
# Out:
# ((2349, 10), (3632, 10), (3569, 10))

# %%
dfs0.shape
# Out:
# (2349, 10)

# %%
svrs0 = dfs0[dfs0['Processing Delay (ms)'] > latency_bound] 
svrs0
# Out:
#               Time Model Name File Name  Propagation Delay (s)  \
# 0     1.721423e+09      small     6.jpg               0.528287
# 16    1.721423e+09      small     6.jpg               0.154325
# 17    1.721423e+09      small     6.jpg               0.551863
# 33    1.721423e+09      small     6.jpg               0.152584
# 34    1.721423e+09      small     6.jpg               0.733049
# ...            ...        ...       ...                    ...
# 2325  1.721426e+09      small     6.jpg               0.256119
# 2332  1.721426e+09      small     6.jpg               0.608940
# 2334  1.721426e+09      small     6.jpg               0.488011
# 2335  1.721426e+09      small     6.jpg               0.232011
# 2336  1.721426e+09      small     6.jpg               0.507908
#
#       Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0               5486.490488       6.047972  belgium   500       44.9  1000
# ...

# %%
dfs1.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721421e+09      small     6.jpg               0.517642
# 1  1.721421e+09      small     6.jpg               0.630199
# 2  1.721421e+09      small     6.jpg               0.988662
# 3  1.721421e+09      small     6.jpg               0.223151
# 4  1.721421e+09      small     6.jpg               0.394324
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            3280.420542       3.835097  belgium  1000       44.9  1000
# 1             488.828182       1.136378  belgium  1000       44.9  1000
# 2             480.044127       1.490798  belgium  1000       44.9  1000
# 3             497.664928       0.739612  belgium  1000       44.9  1000
# 4             484.086514       0.905671  belgium  1000       44.9  1000

# %%
svrs1 = dfs1[dfs1['Processing Delay (ms)'] > latency_bound] 
svrs1
# Out:
#              Time Model Name File Name  Propagation Delay (s)  \
# 0    1.721421e+09      small     6.jpg               0.517642
# 240  1.721422e+09      small     6.jpg              19.450556
# 255  1.721422e+09      small     6.jpg               2.882343
#
#      Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0              3280.420542       3.835097  belgium  1000       44.9  1000
# 240            1109.298229      20.588278  belgium  1000       44.9  1000
# 255            1810.436249       4.726373  belgium  1000       44.9  1000

# %%
dfs15.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721420e+09      small     6.jpg               0.287979
# 1  1.721420e+09      small     6.jpg               0.384897
# 2  1.721420e+09      small     6.jpg               0.621610
# 3  1.721420e+09      small     6.jpg               0.243008
# 4  1.721420e+09      small     6.jpg               0.294014
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            3290.763855       3.601072  belgium  1500       44.9  1000
# 1             476.178885       0.879406  belgium  1500       44.9  1000
# 2             526.332378       1.173266  belgium  1500       44.9  1000
# 3             512.504339       0.774726  belgium  1500       44.9  1000
# 4             485.648870       0.798178  belgium  1500       44.9  1000

# %%
svrs15 = dfs15[dfs15['Processing Delay (ms)'] > latency_bound] 
svrs15
# Out:
#               Time Model Name File Name  Propagation Delay (s)  \
# 0     1.721420e+09      small     6.jpg               0.287979
# 2046  1.721422e+09      small     6.jpg               2.836779
#
#       Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0               3290.763855       3.601072  belgium  1500       44.9  1000
# 2046            1241.518497       4.100210  belgium  1500       44.9  1000

# %%
plt.figure(figsize=(12,4))
plt.plot(dfs0.index[1:], dfs0['Processing Delay (ms)'][1:], label='500 - Small')
plt.plot(dfs1.index[1:], dfs1['Processing Delay (ms)'][1:], label='1000 - Small')
plt.plot(dfs15.index[1:], dfs15['Processing Delay (ms)'][1:], label='1500 - Small')

plt.grid()
plt.legend()
plt.ylim([0,1200])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(dfn1.index[1:], dfn1['Processing Delay (ms)'][1:], label='1000 - Nano')
plt.plot(dfs1.index[1:], dfs1['Processing Delay (ms)'][1:], label='1000 - Small')
plt.plot(dfm1.index[1:], dfm1['Processing Delay (ms)'][1:], label='1000 - Medium')

plt.grid()
plt.legend()
plt.ylim([0,1500])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()

# %% [markdown]
# ## Medium

# %%
## MEDIUM
dfm0 = pd.read_csv('yolov8/logs/medium/dataset_yolo8m_b0_20240718_183936.csv')
dfm1 = pd.read_csv('yolov8/logs/medium/dataset_yolo8m_b1_20240718_192859.csv')
dfm15 = pd.read_csv('yolov8/logs/medium/dataset_yolo8m_b15_20240718_200015.csv')
dfm0.shape, dfm1.shape, dfm15.shape
# Out:
# ((1000, 10), (1000, 10), (1000, 10))

# %%
dfm0.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721324e+09     medium     6.jpg               0.541315
# 1  1.721324e+09     medium     6.jpg               0.249562
# 2  1.721324e+09     medium     6.jpg               0.571447
# 3  1.721324e+09     medium     6.jpg               0.510918
# 4  1.721324e+09     medium     6.jpg               0.441990
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            7592.634201       8.157933  belgium   500       50.2  1000
# 1            2133.477449       2.399386  belgium   500       50.2  1000
# 2            2114.082813       2.716908  belgium   500       50.2  1000
# 3            2086.592197       2.612692  belgium   500       50.2  1000
# 4            2068.046093       2.533227  belgium   500       50.2  1000

# %%
dfm1.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721327e+09     medium     6.jpg               0.668405
# 1  1.721327e+09     medium     6.jpg               0.242030
# 2  1.721327e+09     medium     6.jpg               0.345527
# 3  1.721327e+09     medium     6.jpg               6.606554
# 4  1.721327e+09     medium     6.jpg               0.445703
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            4173.984289       4.871006  belgium  1000       50.2  1000
# 1            1095.102787       1.352524  belgium  1000       50.2  1000
# 2            1050.531387       1.420837  belgium  1000       50.2  1000
# 3            1056.902170       7.682641  belgium  1000       50.2  1000
# 4            1067.917824       1.535941  belgium  1000       50.2  1000

# %%
dfm15.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721329e+09     medium     6.jpg               0.350405
# 1  1.721329e+09     medium     6.jpg               0.258499
# 2  1.721329e+09     medium     6.jpg               0.407944
# 3  1.721329e+09     medium     6.jpg               0.223958
# 4  1.721329e+09     medium     6.jpg               0.851219
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            4145.478725       4.525102  belgium  1500       50.2  1000
# 1            1087.746382       1.367511  belgium  1500       50.2  1000
# 2            1244.469404       1.683694  belgium  1500       50.2  1000
# 3            1106.155396       1.352068  belgium  1500       50.2  1000
# 4            1112.578869       1.988330  belgium  1500       50.2  1000

# %%
plt.figure(figsize=(12,4))
plt.plot(dfm0.index[1:], dfm0['Processing Delay (ms)'][1:], label='Medium Half')
plt.plot(dfm1.index[1:], dfm1['Processing Delay (ms)'][1:], label='Medium One')
plt.plot(dfm15.index[1:], dfm15['Processing Delay (ms)'][1:], label='Medium 15')

plt.grid()
plt.legend()
plt.ylim([0,2500])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(dfn15.index[1:], dfn15['Processing Delay (ms)'][1:], label='1500 - Nano')
plt.plot(dfs15.index[1:], dfs15['Processing Delay (ms)'][1:], label='1500 - Small')
plt.plot(dfm15.index[1:], dfm15['Processing Delay (ms)'][1:], label='1500 - Medium')

plt.grid()
plt.legend()
plt.ylim([0,1500])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()

# %% [markdown]
# ## Large

# %%
## MEDIUM
dfl0 = pd.read_csv('yolov8/logs/large/dataset_yolo8l_b0_20240719_115028.csv')
dfl1 = pd.read_csv('yolov8/logs/large/dataset_yolo8l_b1_20240719_145157.csv')
dfl15 = pd.read_csv('yolov8/logs/large/dataset_yolo8l_b15_20240719_154330.csv')
dfl0.shape, dfl1.shape, dfl15.shape
# Out:
# ((1000, 10), (1000, 10), (1000, 10))

# %%
dfl0.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721386e+09      large     6.jpg               0.497765
# 1  1.721386e+09      large     6.jpg               0.307281
# 2  1.721386e+09      large     6.jpg               0.552030
# 3  1.721386e+09      large     6.jpg               0.297059
# 4  1.721386e+09      large     6.jpg               0.527102
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0           10465.763569      11.010450  belgium   500       52.9  1000
# 1            4040.558815       4.370199  belgium   500       52.9  1000
# 2            4077.525377       4.652573  belgium   500       52.9  1000
# 3            4102.123737       4.420527  belgium   500       52.9  1000
# 4            4170.653343       4.722630  belgium   500       52.9  1000

# %%
dfl1.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721397e+09      large     6.jpg               0.432567
# 1  1.721397e+09      large     6.jpg               0.217915
# 2  1.721397e+09      large     6.jpg               0.348430
# 3  1.721397e+09      large     6.jpg               0.279478
# 4  1.721397e+09      large     6.jpg               0.665898
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            6723.399878       7.183622  belgium  1000       52.9  1000
# 1            2055.487156       2.288770  belgium  1000       52.9  1000
# 2            2097.448826       2.481055  belgium  1000       52.9  1000
# 3            2135.996580       2.436691  belgium  1000       52.9  1000
# 4            2028.857708       2.717773  belgium  1000       52.9  1000

# %%
dfl15.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721400e+09      large     6.jpg               0.353024
# 1  1.721400e+09      large     6.jpg               0.182034
# 2  1.721400e+09      large     6.jpg               0.369559
# 3  1.721400e+09      large     6.jpg               0.176344
# 4  1.721400e+09      large     6.jpg               0.561884
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            5785.578966       6.169131  belgium  1500       52.9  1000
# 1            2134.243727       2.337931  belgium  1500       52.9  1000
# 2            2104.139805       2.499139  belgium  1500       52.9  1000
# 3            2100.451946       2.297104  belgium  1500       52.9  1000
# 4            2079.942703       2.666088  belgium  1500       52.9  1000

# %%
plt.figure(figsize=(12,4))
plt.plot(dfl0.index[1:], dfl0['Processing Delay (ms)'][1:], label='Medium Half')
plt.plot(dfl1.index[1:], dfl1['Processing Delay (ms)'][1:], label='Medium One')
plt.plot(dfl15.index[1:], dfm15['Processing Delay (ms)'][1:], label='Medium 15')

plt.grid()
plt.legend()
plt.ylim([0,5000])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(dfn0.index[1:], dfn0['Processing Delay (ms)'][1:], label='500 - Nano')
plt.plot(dfs0.index[1:], dfs0['Processing Delay (ms)'][1:], label='500 - Small')
plt.plot(dfm0.index[1:], dfm0['Processing Delay (ms)'][1:], label='500 - Medium')
#plt.plot(dfl0.index[1:], dfl0['Processing Delay (ms)'][1:], label='500 - Large')

plt.grid()
plt.legend()
plt.ylim([0,2500])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(dfn1.index[1:], dfn1['Processing Delay (ms)'][1:], label='1000 - Nano')
plt.plot(dfs1.index[1:], dfs1['Processing Delay (ms)'][1:], label='1000 - Small')
plt.plot(dfm1.index[1:], dfm1['Processing Delay (ms)'][1:], label='1000 - Medium')
#plt.plot(dfl1.index[1:], dfl1['Processing Delay (ms)'][1:], label='1000 - Large')

plt.grid()
plt.legend()
plt.ylim([0,1500])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(dfn15.index[1:], dfn15['Processing Delay (ms)'][1:], label='1500 - Nano')
plt.plot(dfs15.index[1:], dfs15['Processing Delay (ms)'][1:], label='1500 - Small')
plt.plot(dfm15.index[1:], dfm15['Processing Delay (ms)'][1:], label='1500 - Medium')
#plt.plot(dfl15.index[1:], dfl15['Processing Delay (ms)'][1:], label='1500 - Large')

plt.grid()
plt.legend()
plt.ylim([0,1500])
plt.xlabel('Index')
plt.ylabel('Processing Delay (s)')
plt.show()

# %% [markdown]
# # Motivation

# %%
df = [dfn0, dfn1, dfn15, dfs0, dfs1, dfs15, dfm0, dfm1, dfm15]
df = pd.concat(df, axis=0)
df.reset_index(drop=True, inplace=True)
latency_bound = 800  # in ms

# %%
df.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721411e+09       nano     6.jpg               0.609235
# 1  1.721411e+09       nano     6.jpg               0.246938
# 2  1.721411e+09       nano     6.jpg               0.568292
# 3  1.721411e+09       nano     6.jpg               0.377092
# 4  1.721411e+09       nano     6.jpg               0.569254
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            4696.698427       5.334612  belgium   500       37.3  1000
# 1             369.429111       0.643364  belgium   500       37.3  1000
# 2             427.781105       1.027048  belgium   500       37.3  1000
# 3             391.561508       0.796242  belgium   500       37.3  1000
# 4             401.158094       0.998305  belgium   500       37.3  1000

# %%
svr = df[df['Processing Delay (ms)'] > latency_bound]
# Count SLA violations for each core
svr_counts = svr.groupby(['Model Name','core']).size().reset_index(name='violation_count')
svr_counts['per_core_violations'] = (svr_counts['violation_count']/1000)*100

# %%
svr_counts
# Out:
#   Model Name  core  violation_count  violation_rate
# 0     medium   500             1000           100.0
# 1     medium  1000             1000           100.0
# 2     medium  1500             1000           100.0
# 3       nano   500                1             0.1
# 4       nano  1000                1             0.1
# 5       nano  1500                1             0.1
# 6      small   500             2159           215.9
# 7      small  1000                3             0.3
# 8      small  1500                2             0.2

# %%
# Generate all possible combinations of model and core
models = df['model'].unique()
cores = df['core'].unique()

all_combinations = pd.DataFrame(list(itertools.product(models, cores)), columns=['model', 'core'])

# Merge with sla_violation_counts to ensure all combinations are included
complete_sla_violation_counts = all_combinations.merge(sla_violation_counts, on=['model', 'core'], how='left')
# Fill missing values with zero
complete_sla_violation_counts['violation_count'] = complete_sla_violation_counts['violation_count'].fillna(0)
complete_sla_violation_counts['per_core_violations'] = complete_sla_violation_counts['per_core_violations'].fillna(0)
sla_violate =  complete_sla_violation_counts
